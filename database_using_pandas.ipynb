# %% [markdown]
# <a href="https://colab.research.google.com/github/shivankart9/ai-lab-college/blob/main/database_using_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Input data
names = ["suraj", "shivankar", "shiv", "ram", "syam", "aarav", "sachin", "vinayak", "rishi", "sandeep"]
ages = [18, 19, 40, 50, 100, 80, 90, 78, 23, 34]

# Create DataFrame
df = pd.DataFrame({
    "Name": names,
    "Age": ages
})

# Display the DataFrame
print(df)
# Out:
#         Name  Age
# 0      suraj   18
# 1  shivankar   19
# 2       shiv   40
# 3        ram   50
# 4       syam  100
# 5      aarav   80
# 6     sachin   90
# 7    vinayak   78
# 8      rishi   23
# 9    sandeep   34
