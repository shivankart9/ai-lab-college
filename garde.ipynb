# %% [markdown]
# <a href="https://colab.research.google.com/github/shivankart9/ai-lab-college/blob/main/garde.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = int(input("enter the num1 : "))
if(marks>=80):
  print("A grade")
elif marks>=60 and marks<=79:
  print("B grade")
elif marks>=40 and marks<=59:
  print("C grade")
else:
  print("fail")
# Out:
# enter the num1 : 78
# B grade
